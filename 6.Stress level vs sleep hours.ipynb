# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./Downloads/Mental Health.csv')
remote_impact = pd.crosstab(df['stress_level'], df['sleep_hours'])
remote_impact.plot(kind='bar', stacked=True, color=['#8ecae6', '#219ebc'])
plt.title("stress level vs sleep hours")
plt.xlabel("st ress")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_112949/1984489723.py:10: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
